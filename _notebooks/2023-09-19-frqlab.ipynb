// %% [markdown]
// ---
// layout: post
// title: FRQ Mini Lab - Methods & Control Structures
// description: FUN FUN FUN
// toc: true
// comments: true
// categories: [C5.0]
// courses: { csse: {week: 2}, csp: {week: 1, categories: [4.B, 5.B]}, csa: {week: 4} }
// type: devops
// ---

// %% [markdown]
// <h1>About AP CSA Exam</h1>
//
// <b>Section I: Multiple Choice </b>
//
// 40 Questions | 1 Hour 30 Minutes | 50% of Exam Score
//
// The multiple-choice section includes mostly individual questions, occasionally with 1–2 sets of questions (2 questions per set).
// Computational Thinking Practices 1, 2, 4, and 5 are all assessed in the multiple-choice section.
//
// <b>Section II: Free Response</b>
//
// 4 Questions | 1 Hour 30 Minutes | 50% of Exam Score
//
// All free-response questions assess Computational Thinking Practice 3: Code Implementation, with the following focus:
//
// Q1: Methods and Control Structures—Students will be asked to write program code to create objects of a class and call methods, and satisfy method specifications using expressions, conditional statements, and iterative statements.
//
// <mark>Q2: Classes </mark>—Students will be asked to write program code to define a new type by creating a class and satisfy method specifications using expressions, conditional statements, and iterative statements.
//
// Q3: Array/ArrayList—Students will be asked to write program code to satisfy method specifications using expressions, conditional statements, and iterative statements and create, traverse, and manipulate elements in 1D array or ArrayList objects.
//
// Q4: 2D Array—Students will be asked to write program code to satisfy method specifications using expressions, conditional statements, and iterative statements and create, traverse, and manipulate elements in 2D array objects.
//
// <b>Free Response notes to keep in mind</b>
//
// 1 point penalty
// - Array/collection access confusion ([] get): issue with how you are trying to access certain elements in an array/collection
// - Extraneous code that causes SIDE EFFECT (printing to output, incorrect precondition check)
// - Local variables used but none declared
// - Destruction of persistent data (e.g. changing value referenced by parameter)
// - Void method or constructor that returns a value
//
// No penalty but common error
// - Mispelling w/no ambiguity
// - Missing ; when structure clearly conveys intent
// - Missing { } where identation clearly conveys intent

// %% [markdown]
// <h2>Review of Classes concepts</h2>
//
// Logistical example of thinking about the anatomy of a class:
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/f1f98197-51bb-4dfe-84ad-3f9417462de7)
//
// Basic structure on AP exam:
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/4ff5db9a-506c-46f3-938b-b8877577ff58)
//
// Constructing an Object using a Class
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/4b453bc1-7eb8-45ef-a487-4810feecb15a)
//
// Using Our Object
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/fcff3bf3-aa6f-447d-b5e2-f8c0f67f72bc)
//
// <b>STATIC METHODS!</b>
//
// - Cannot be instantiated, associated w/class itself rather than instances of the class. Cannot create objects of a static class
// - Use cases: Need to encapsulate utilimity methods, constants, or shared resources that are not tied to any particular instance. Ex. a "Math" class may have static methods for mathematical operations.
// - Use class.method() convention
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/284ff4d0-6bae-4d81-9b38-8a5935fb527f)
//
// <b> STRING CLASS OBJECTS!</b>
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/857f089d-1ec7-4580-acea-f2c21115a9b6)

// %% [markdown]
// <h2> MC Practice </h2>
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/ee94f560-35d0-4a15-b46a-38702d495dff)
//
// A: empty parameter list
//
// B & C: declaring brand new variables inside parameter list ==> not valid syntax
//
// D: CORRECT ANSWER
//
// E: Cannot pass double parameter into integer value
//
// ![](https://github.com/e-shen2022/APCS_Blog/assets/104966589/88d3575d-7329-4912-a282-c8ee78c7a184)
//
// A: Pass 4 double instead of 2
//
// B: Same as A
//
// C: Calling constructor with empty parameter list, end1 and end2 are private and not in client program
//
// D: Empty parameter list
//
// E: Instantiate 2 objects with correct values, correctly call Line constructor pasing in p1 and p2 are parameters

// %%
public class Book 
{
    private String title; 
    private double price; 
    public Book (String bookTitle, double bookPrice)
    {
        title = bookTitle;
        price = bookPrice;
    }
    public String getTitle() 
    {
        return title; 
    }

    public double getPrice() {
        return price; 
    }

    public String getBookInfo()
    {
        return title + " $" + price; 
    }
}

// Solution: 9 TOTAL POINTS

// 1. Declares class header (must not be private)
public class Textbook extends Book 
{
    private int edition; 

    // 2. Declares constructor header - taking 3 parameters, define type of variable 
    public Textbook(String tbTitle, double tbPrice, int edition) {
        // 3. Call super (parent class) instructor from book class as the first line w/appropiate parameters 
        super(tbTitle, tbPrice);
        // 4. Declares appropiate private instance variable & uses to appropiate parameter to intialize it 
        this.edition = edition;
    }

    // 5. Declares AT LEAST 1 required method & all declared headers are correct 
    // 6. getEdition returns value of instance variable 
    // GETTER method that returns edition of textbook 
    public int getEdition() {
        return edition; 
    }

    // 5. 
    // 7. determines whether true or false should be returned based on comparison of book titles and editions (algorithms)
    // Takes another "textbook" object as a parameter, compares titles & currents if edition is equal or greater
    // If true then current textbook can sub for other, otherwise return false 
    public boolean canSubstituteFor(Textbook otherTextbook) {
        return this.getTitle().equals(otherTextbook.getTitle()) && this.edition >= otherTextbook.getEdition(); 
    }
    // 5. 
    // 8. getBookInfo calls super.getBookInfo 
    // 9. Constructs info string (return is not assessed for this method) 
    // Gets book info (title & price) and appends edition to end of string 
    public String getBookInfo() {
        return super.getBookInfo() + " - Edition " + edition; 
    
    }
}

// %% [markdown]
// <h1>Testing output!</h1>

// %%
public class Main {
    public static void main(String[] args) {

        // Instance for English textbook
        Textbook engTextbook = new Textbook("English", 121.10, 6);
        System.out.println("Book Information: " + engTextbook.getBookInfo());
        
        // Instance for Biology textbook
        Textbook bioTextbook = new Textbook("Biology", 190.32, 8);
        System.out.println("Book Information: " + bioTextbook.getBookInfo());

        // Check if can subsitute
        System.out.println("\nCan this English textbook replace this Biology textbook? " + engTextbook.canSubstituteFor(bioTextbook));

        // Instance for higher edition English textbook
        Textbook eng2Textbook = new Textbook("English", 600.32, 7);
  
        // check if the calculus textbook can substitute for the other calculus textbook
        System.out.println("\nCan this 7th edition English textbook substitute for this 6th edition English textbook? " + eng2Textbook.canSubstituteFor(engTextbook));
      
    }
}

Main.main(null);
// Out:
// Book Information: English $121.1 - Edition 6
// Book Information: Biology $190.32 - Edition 8
//
// Can this English textbook replace this Biology textbook? false
//
// Can this 7th edition English textbook substitute for this 6th edition English textbook? true
